# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Set styles for the plots
sns.set(style='whitegrid')

#pandas: Used for data manipulation and analysis.
#matplotlib.pyplot: Used for creating static, animated, and interactive visualizations.
#seaborn: A data visualization library based on matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
df = pd.read_csv(r'C:\Users\satya\Downloads\Python_Diwali_Sales_Analysis\Diwali Sales Data.csv', encoding='unicode_escape')
#df = data frame stored in python 
# pd.read_csv() = read a csv file into data frame
#r" raw string notation helps to handle file in windows
# ecoding= 'unicode_escape' = ensures file  can be read correctly, handle any special charcters

# %%
print(df.head())
df.info()

#df.head() = displays first 5 row of data frame, you can ask for more by putting df.read(10) and more
#df.info() = displays column names, non-null count, data type (dtype), memory usage display amount of memory used by data frame
#df.describe() = provides statistics suchh as count, mean, standard deviation, minimum. max, 25th %, 75 %, for numerical values
#df.shape() = print out number or rowa and coloumns in dataframe.
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.drop({'Status' , 'unnamed1'}, axis =1 , inplace = True)
#run again thats why shwing error as next step have already deleted the blank cell
#help to drop, turncate blank coloumns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.drop({'Status' , 'unnamed1'}, axis =1 , inplace = True)
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
#help to get true/false value in dataframe it means values are there then showing false
#and if true showing means null/blank cell is there.
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()
#will help to get sum of total false in dataframe
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11251, 13)

# %%
print(df.isnull().sum())
df.dropna(inplace= True)

#(df.isnull().sum()) = helps to bring missing values in each coloumn
#df.dropna(inplace= True) = helps to remove with missing values
#inplace help to safe after any changes
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
print(df['Amount'].isnull().sum())  # Check for missing values in the 'Amount' column
df['Amount'].fillna(0, inplace=True)  # Fill missing values with 0
# Out:
# 12

# %%
df['Amount'] = df['Amount'].astype('int')
#converted float to int

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
df.rename(columns={'unnamed1': 'unknown'}, inplace=True)
#rename columns

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marriage', 'State', 'Zone', 'Occupation', 'Product_Category', 'Orders',
#        'Amount', 'Status', 'unknown'],
#       dtype='object')

# %%
df.describe()
# Out:
#             User_ID           Age      Marriage        Orders        Amount  \
# count  1.125100e+04  11251.000000  11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207      0.420318      2.489290   9443.527598
# std    1.716125e+03     12.754122      0.493632      1.115047   5228.683337
# min    1.000001e+06     12.000000      0.000000      1.000000      0.000000
# 25%    1.001492e+06     27.000000      0.000000      1.500000   5440.000000
# 50%    1.003065e+06     33.000000      0.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000      1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000      1.000000      4.000000  23952.000000
#
#        Status  unknown
# count     0.0      0.0
# mean      NaN      NaN
# std       NaN      NaN
# min       NaN      NaN
# 25%       NaN      NaN
# 50%       NaN      NaN
# 75%       NaN      NaN
# max       NaN      NaN

# %%
df[['Age', 'Marriage']].describe()
# Out:
#                 Age      Marriage
# count  11251.000000  11251.000000
# mean      35.421207      0.420318
# std       12.754122      0.493632
# min       12.000000      0.000000
# 25%       27.000000      0.000000
# 50%       33.000000      0.000000
# 75%       43.000000      1.000000
# max       92.000000      1.000000

# %% [markdown]
# EXPLATORY DATA ANALYSIS

# %% [markdown]
# Gender

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Gender', data=df)
plt.show()

# %%
ax = sns.countplot(x = 'Gender', data=df)
for bar in ax.containers:
    ax.bar_label(bar)

plt.show()

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# %%
sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Bar plot
ax = sns.barplot(x='Gender', y='Amount', data=sales_gen)

# Show bar labels in readable format
for container in ax.containers:
    ax.bar_label(container, fmt='{:,.0f}')  # Adds commas and removes scientific notation

# Show the plot
plt.show()

# %% [markdown]
# ABOVE GRAPH CLEARLY SHOWS THAT FEMALE HAS HIGH PURCHASING POWER THAN MALE

# %% [markdown]
# AGE

# %%
ax = sns.countplot(data = df, x='Age Group', hue='Gender')

for bars in ax.containers:
    ax.bar_label(bars)

#hue helps to defferniate the gender0

# %%
# Total Amount vs Age Group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# ABOVE GRAPH CLEARLY SHOWS THAT AGE GROUP BETWEEN 26-35 HAS MORE PURCHASING POWER

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marriage', 'State', 'Zone', 'Occupation', 'Product_Category', 'Orders',
#        'Amount', 'Status', 'unknown'],
#       dtype='object')

# %%
# TTOTAL SALES BY STATES
State_sales = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
#to resize
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x = 'State',y= 'Amount' ,data = State_sales)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# ABOVE GRAPH CLEARLY SHOWS THAT Uttar pradesh have high sales among all states in India

# %%
Zone_sales = df.groupby(['Zone'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
#to resize

sns.barplot(x = 'Zone',y= 'Amount' ,data = Zone_sales)
# Out:
# <Axes: xlabel='Zone', ylabel='Amount'>

# %% [markdown]
# ABOVE GRAPH CLEARLY SHOWS THAT CENTRAL part have high sales among all states in India

# %%
marriage_status_sales = df.groupby(['Marriage'], as_index=False) ['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x='Marriage', y= 'Amount' , data =marriage_status_sales)
# Out:
# <Axes: xlabel='Marriage', ylabel='Amount'>

# %%
Product_sales= df.groupby(['Product_Category'], as_index= False) ['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Product_Category', y='Amount' , data= Product_sales)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
Occupation_sales= df.groupby(['Occupation'], as_index= False) ['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x='Occupation', y='Amount' , data= Occupation_sales)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# Married women age group 26-35 yrs from UP, Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category
